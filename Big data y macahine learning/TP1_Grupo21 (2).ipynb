# %% [markdown]
# # Big Data y Machine Learning (UBA) -  2025
#
# ## Trabajo Práctico 1: Jugando con APIs y WebScraping

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar debidamente documentado comentado (utilizando #) para que tanto los docentes como sus compañeros puedan comprender el código fácilmente.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Viernes 4 de Abril a las 13:00 hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub llamado “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 deben estar dentro de esa carpeta.
# - También deben enviar el link de su repositorio -para que pueda ser clonado y corregido- a mi correo 25RO35480961@campus.economicas.uba.ar. Usar de asunto de email <i>"Big Data - TP 1 - Grupo #"</i> y nombrar el archivo <i>"TP1_Grupo #"</i> donde # es el número de grupo que le fue asignado.
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No envien el correo hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar.
#     - No hagan nuevos <i>push</i> despues de haber entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.
# - En resumen, la carpeta del repositorio debe incluir:
#     - El codigo
#     - Un documento Word (Parte A) donde esten las figuras y una breve descripción de las mismas.
#     - El excel con los links webscrappeados (Parte B)

# %% [markdown]
# ### Parte A

# %% [markdown]
# #### Ejercicio 1 - Jugando con APIs
# Usando la API del Banco Mundial [link](https://wbdata.readthedocs.io/en/stable/) , obtener dos series de indicadores para dos paises a elección en una consulta de búsqueda. Pueden buscar serie de indicadores de su interés.

# %%
# !pip install wbdata pandas

import wbdata
import pandas as pd
import datetime
# Out:
# Requirement already satisfied: wbdata in c:\users\gabar\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: pandas in c:\users\gabar\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: appdirs<2.0,>=1.4 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (1.4.4)
# Requirement already satisfied: backoff<3.0.0,>=2.2.1 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (2.2.1)
# Requirement already satisfied: cachetools<6.0.0,>=5.3.2 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (5.3.3)
# Requirement already satisfied: dateparser<2.0.0,>=1.2.0 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (1.2.1)
# Requirement already satisfied: decorator<6.0.0,>=5.1.1 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3.0,>=2.0 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (2.32.3)
# Requirement already satisfied: shelved-cache<0.4.0,>=0.3.1 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (0.3.1)
# Requirement already satisfied: tabulate<0.9.0,>=0.8.5 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (0.8.10)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gabar\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gabar\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gabar\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gabar\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in c:\users\gabar\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2024.9.11)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\gabar\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (5.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\gabar\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gabar\anaconda3\lib\site-packages (from requests<3.0,>=2.0->wbdata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gabar\anaconda3\lib\site-packages (from requests<3.0,>=2.0->wbdata) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gabar\anaconda3\lib\site-packages (from requests<3.0,>=2.0->wbdata) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gabar\anaconda3\lib\site-packages (from requests<3.0,>=2.0->wbdata) (2025.1.31)

# %%
# !pip3 install -U wbdata
# Out:
# Requirement already satisfied: wbdata in c:\users\gabar\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: appdirs<2.0,>=1.4 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (1.4.4)
# Requirement already satisfied: backoff<3.0.0,>=2.2.1 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (2.2.1)
# Requirement already satisfied: cachetools<6.0.0,>=5.3.2 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (5.3.3)
# Requirement already satisfied: dateparser<2.0.0,>=1.2.0 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (1.2.1)
# Requirement already satisfied: decorator<6.0.0,>=5.1.1 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (5.1.1)
# Requirement already satisfied: requests<3.0,>=2.0 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (2.32.3)
# Requirement already satisfied: shelved-cache<0.4.0,>=0.3.1 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (0.3.1)
# Requirement already satisfied: tabulate<0.9.0,>=0.8.5 in c:\users\gabar\anaconda3\lib\site-packages (from wbdata) (0.8.10)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\gabar\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2024.2 in c:\users\gabar\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2025.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in c:\users\gabar\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (2024.9.11)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\gabar\anaconda3\lib\site-packages (from dateparser<2.0.0,>=1.2.0->wbdata) (5.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gabar\anaconda3\lib\site-packages (from requests<3.0,>=2.0->wbdata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gabar\anaconda3\lib\site-packages (from requests<3.0,>=2.0->wbdata) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gabar\anaconda3\lib\site-packages (from requests<3.0,>=2.0->wbdata) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gabar\anaconda3\lib\site-packages (from requests<3.0,>=2.0->wbdata) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\gabar\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->dateparser<2.0.0,>=1.2.0->wbdata) (1.16.0)
# Requirement already satisfied: tzdata in c:\users\gabar\anaconda3\lib\site-packages (from tzlocal>=0.2->dateparser<2.0.0,>=1.2.0->wbdata) (2023.3)

# %%
import wbdata
wbdata.get_sources(63)
wbdata.get_indicators(source=63)
# Out:
# id                 name
# -----------------  ----------------------------------------------------------
# HD.HCI.AMRT        Survival Rate from Age 15-60
# HD.HCI.AMRT.FE     Survival Rate from Age 15-60, Female
# HD.HCI.AMRT.MA     Survival Rate from Age 15-60, Male
# HD.HCI.EYRS        Expected Years of School
# HD.HCI.EYRS.FE     Expected Years of School, Female
# HD.HCI.EYRS.MA     Expected Years of School, Male
# HD.HCI.HLOS        Harmonized Test Scores
# HD.HCI.HLOS.FE     Harmonized Test Scores, Female
# HD.HCI.HLOS.MA     Harmonized Test Scores, Male
# HD.HCI.LAYS        Learning-Adjusted Years of School
# HD.HCI.LAYS.FE     Learning-Adjusted Years of School, Female
# HD.HCI.LAYS.MA     Learning-Adjusted Years of School, Male
# HD.HCI.MORT        Probability of Survival to Age 5
# HD.HCI.MORT.FE     Probability of Survival to Age 5, Female
# HD.HCI.MORT.MA     Probability of Survival to Age 5, Male
# HD.HCI.OVRL        Human Capital Index (HCI) (scale 0-1)
# HD.HCI.OVRL.FE     Human Capital Index (HCI), Female (scale 0-1)
# HD.HCI.OVRL.LB     Human Capital Index (HCI), Lower Bound (scale 0-1)
# HD.HCI.OVRL.LB.FE  Human Capital Index (HCI), Female, Lower Bound (scale 0-1)
# HD.HCI.OVRL.LB.MA  Human Capital Index (HCI), Male, Lower Bound (scale 0-1)
# HD.HCI.OVRL.MA     Human Capital Index (HCI), Male (scale 0-1)
# HD.HCI.OVRL.UB     Human Capital Index (HCI), Upper Bound (scale 0-1)
# HD.HCI.OVRL.UB.FE  Human Capital Index (HCI), Female, Upper Bound (scale 0-1)
# HD.HCI.OVRL.UB.MA  Human Capital Index (HCI), Male, Upper Bound (scale 0-1)
# HD.HCI.STNT        Fraction of Children Under 5 Not Stunted
# HD.HCI.STNT.FE     Fraction of Children Under 5 Not Stunted, Female
# HD.HCI.STNT.MA     Fraction of Children Under 5 Not Stunted, Male

# %%
wbdata.get_countries(query='USA')
wbdata.get_data("HD.HCI.AMRT.MA", country="USA")
# Out:
# [{'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 0.861651420593262,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 0.860060155391693,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 0.8759,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 0.865807294845581,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1}]

# %%
wbdata.get_data("HD.HCI.AMRT.MA", country=["USA", "ARG"], date=("2010", "2020"))
# Out:
# [{'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2020',
#   'value': 0.854534029960632,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2019',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2018',
#   'value': 0.851294696331024,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2017',
#   'value': 0.8511,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2014',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2013',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2012',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2011',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'AR', 'value': 'Argentina'},
#   'countryiso3code': 'ARG',
#   'date': '2010',
#   'value': 0.838681995868683,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2020',
#   'value': 0.861651420593262,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 0.860060155391693,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 0.8759,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1},
#  {'indicator': {'id': 'HD.HCI.AMRT.MA',
#    'value': 'Survival Rate from Age 15-60, Male'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 0.865807294845581,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 1}]

# %%
wbdata.get_indicators(query="gdp per capita", source=2)
wbdata.get_incomelevels()
# Out:
# id    value
# ----  -------------------
# HIC   High income
# INX   Not classified
# LIC   Low income
# LMC   Lower middle income
# LMY   Low & middle income
# MIC   Middle income
# UMC   Upper middle income

# %%
countries = [i['id'] for i in wbdata.get_countries(incomelevel='HIC')]

indicators = {"HD.HCI.AMRT.MA": "human_capital_index", "NY.GDP.PCAP.PP.KD": "gdppc"}

df = wbdata.get_dataframe(indicators, country=countries, parse_dates=True)

df.describe()
# Out:
#        human_capital_index          gdppc
# count           228.000000    2375.000000
# mean              0.885489   45482.828315
# std               0.059390   24905.643885
# min               0.636252    5074.430935
# 25%               0.854840   28483.838641
# 50%               0.908743   41191.031240
# 75%               0.928409   57237.530972
# max               0.959156  174339.077325

# %%
In [13]: df.sort_index().groupby('country').last().corr()
# Out:
#                      human_capital_index     gdppc
# human_capital_index             1.000000  0.482048
# gdppc                           0.482048  1.000000

# %% [markdown]
# #### Ejercicio 2 - Repaso de Pandas
# Realicen una estadistica descriptiva de ambas series de indicadores comparando los dos países.

# %%
# Resolver acá
import pandas as pd
import wbdata

# Parámetros que buscamos

indicators = {"HD.HCI.AMRT.MA": "human_capital_index", "NY.GDP.PCAP.PP.KD": "gdppc"}
country = ["USA", "ARG"]
date = ("2010", "2020")
freq = 'Y'
parse_dates = True
keep_levels = False
skip_cache = False


wbdata.get_dataframe(indicators = indicators,
                     country=country,
                     date=date,
                     freq=freq,
                     parse_dates=parse_dates,
                     keep_levels=keep_levels,
                     skip_cache=skip_cache)
# Out:
#                           human_capital_index         gdppc
# country       date
# Argentina     2020-01-01             0.854534  23877.093140
#               2019-01-01                  NaN  26629.552942
#               2018-01-01             0.851295  27367.115094
#               2017-01-01             0.851100  28334.904185
#               2016-01-01                  NaN  27802.105720
#               2015-01-01                  NaN  28669.206134
#               2014-01-01                  NaN  28200.815257
#               2013-01-01                  NaN  29227.660182
#               2012-01-01                  NaN  28825.966687
#               2011-01-01                  NaN  29425.759388
#               2010-01-01             0.838682  28056.257021
# United States 2020-01-01             0.861651  67352.387139
#               2019-01-01                  NaN  69511.763441
#               2018-01-01             0.860060  68070.213422
#               2017-01-01             0.875900  66458.023373
#               2016-01-01                  NaN  65275.571818
#               2015-01-01                  NaN  64575.408187
#               2014-01-01                  NaN  63191.247781
#               2013-01-01                  NaN  62089.348237
#               2012-01-01                  NaN  61224.405542
#               2011-01-01                  NaN  60294.978803
#               2010-01-01             0.865807  59799.286862

# %%
import wbdata
indicators = {"HD.HCI.AMRT.MA": "human_capital_index", "NY.GDP.PCAP.PP.KD": "gdppc"}
country = ["USA", "ARG"]
date = ("2010", "2020")
freq = 'Y'
parse_dates = True
keep_levels = False
skip_cache = False


wbdata.get_dataframe(indicators = indicators,
                     country=country,
                     date=date,
                     freq=freq,
                     parse_dates=parse_dates,
                     keep_levels=keep_levels,
                     skip_cache=skip_cache)

# %% [markdown]
# #### Ejercicio 3 - Practicando con Matplotlib
# Armen dos gráficos distintos usando la librería Matplotlib (repasen Clase 4). Uno programandolo con el estilo *pyplot* y otro gráfico de estilo *orientada a objetos*

# %%
# Resolver acá estilo pyplot

# %%
# Resolver acá estilo orientado-objetos 
# Tip: aprovechar este estilo de programar una figura para hacerlo más lindo

# %% [markdown]
# ### Parte B

# %% [markdown]
# #### Ejercicio 4
# De la página de noticias del [diario La Nación](https://www.lanacion.com.ar/) o cualquier diario que les interese, utilicen herramientas de web scraping para obtener los **links** de las noticias de la portada. Guarden los links obtenidos en un dataframe y expórtenlo a un archivo de excel.
#
# Nota 1: es posible que logren obtener los links a las noticias sin el dominio: "https://www.lanacion.com.ar/". De ser así, concatenen el dominio a la ruta del link obtenido, tal que se obtenga un link al que se pueda acceder. Es decir, que las cadenas de caracteres finales tendrán la forma: https://www.lanacion.com.ar/*texto_obtenido*)
#
# Nota 2: junto con su entrega, adjunten una captura de la página de noticias al momento de correr su código. Eso servirá al momento de la corrección para verificar que los links obtenidos hacen referencia a las noticias de ese día y hora.

# %%
# Resolver acá

# !pip install requests 
# !pip install beautifulsoup4
# !pip install pandas
# Nota: si no tienen instaladas las librarías a importar debajo, primero deben instalarlas 
# (para eso, quiten el # y activen las 3 líneas de código de arriba)

import requests #html requestor
from bs4 import BeautifulSoup #html parser
import pandas as pd #dataframe manipulator
# Out:
# Requirement already satisfied: requests in c:\users\gabar\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gabar\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\gabar\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gabar\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gabar\anaconda3\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: beautifulsoup4 in c:\users\gabar\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gabar\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: pandas in c:\users\gabar\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gabar\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gabar\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gabar\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gabar\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\gabar\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
url = "https://www.lanacion.com.ar/"

r = requests.get(url) #traigo el contenido del html
contenido = r.content

soup = BeautifulSoup(contenido, "html.parser")
soup

    #Encontrar todos los enlaces
    links = soup.find_all('a')

    # Extraer los enlaces sin el dominio
    enlaces_sin_dominio = []
    for link in links:
        href = link.get('href')
        if href and href.startswith('/'):  # Verifica si es un enlace relativo
            enlaces_sin_dominio.append(href)

    # Mostramos los enlaces sin el dominio
    for enlace in enlaces_sin_dominio:
        print(enlace)
else:
    print(f"Error al acceder a la página: {response.status_code}")
# Out:
#   Cell In[49], line 10
#     links = soup.find_all('a')
#     ^
# IndentationError: unexpected indent
